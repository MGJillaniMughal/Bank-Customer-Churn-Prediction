# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # Importing the data

# %%
df=pd.read_csv('Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.drop(columns=['RowNumber','CustomerId','Surname'],axis=1,inplace=True,)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
X=df.drop(['Exited'],axis=1)
y=df['Exited']

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %% [markdown]
# # Now Convert Object to numberical form

# %%
#Create dummy variables
geography=pd.get_dummies(X["Geography"],drop_first=True)
gender=pd.get_dummies(X['Gender'],drop_first=True)

# %% [markdown]
# ## Concatenate the Data Frames

# %%
X=pd.concat([X,geography,gender],axis=1)

# %%
X.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0          1               1        101348.88        0      0     0
# 1          0               1        112542.58        0      1     0
# 2          1               0        113931.57        0      0     0
# 3          0               0         93826.63        0      0     0
# 4          1               1         79084.10        0      1     0

# %%
## Drop Unnecessary columns
X=X.drop(['Geography','Gender'],axis=1)

# %% [markdown]
# # Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 7)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
X_train=sc.fit_transform(X_train)

# %%
X_test=sc.transform(X_test)

# %% [markdown]
# # Now let's make the ANN!
#
# # Importing the Keras libraries and packages

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %% [markdown]
# # Initialising the ANN

# %%
classifier=Sequential()

# %% [markdown]
# # Adding the input layer and the first hidden layer

# %%
classifier.add(Dense(6, kernel_initializer = 'he_uniform',activation='relu',input_dim = 11))

# %%
# Adding the second hidden layer
classifier.add(Dense(6, kernel_initializer = 'he_uniform',activation='relu'))

# %%
# Adding the output layer
classifier.add(Dense(1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
# Compiling the ANN
classifier.compile(optimizer = 'Adamax', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the ANN to the Training set
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 2s 2ms/step - loss: 0.9640 - accuracy: 0.3517 - val_loss: 0.7232 - val_accuracy: 0.5528
# Epoch 2/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.6420 - accuracy: 0.6921 - val_loss: 0.5868 - val_accuracy: 0.7675
# Epoch 3/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5589 - accuracy: 0.7865 - val_loss: 0.5389 - val_accuracy: 0.7940
# Epoch 4/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.5263 - accuracy: 0.7968 - val_loss: 0.5173 - val_accuracy: 0.7959
# Epoch 5/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5082 - accuracy: 0.7968 - val_loss: 0.5017 - val_accuracy: 0.7963
# Epoch 6/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4918 - accuracy: 0.7964 - val_loss: 0.4880 - val_accuracy: 0.7952
# Epoch 7/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4772 - accuracy: 0.7970 - val_loss: 0.4758 - val_accuracy: 0.7963
# Epoch 8/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4651 - accuracy: 0.7960 - val_loss: 0.4654 - val_accuracy: 0.7982
# Epoch 9/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4552 - accuracy: 0.7987 - val_loss: 0.4563 - val_accuracy: 0.7989
# Epoch 10/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4471 - accuracy: 0.7994 - val_loss: 0.4491 - val_accuracy: 0.8031
# Epoch 11/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4398 - accuracy: 0.8011 - val_loss: 0.4423 - val_accuracy: 0.8042
# Epoch 12/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4333 - accuracy: 0.8048 - val_loss: 0.4362 - val_accuracy: 0.8058
# Epoch 13/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4279 - accuracy: 0.8085 - val_loss: 0.4309 - val_accuracy: 0.8058
# Epoch 14/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4234 - accuracy: 0.8117 - val_loss: 0.4266 - val_accuracy: 0.8118
# Epoch 15/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4192 - accuracy: 0.8119 - val_loss: 0.4225 - val_accuracy: 0.8137
# Epoch 16/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4158 - accuracy: 0.8160 - val_loss: 0.4194 - val_accuracy: 0.8186
# Epoch 17/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4126 - accuracy: 0.8175 - val_loss: 0.4163 - val_accuracy: 0.8209
# Epoch 18/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4097 - accuracy: 0.8199 - val_loss: 0.4138 - val_accuracy: 0.8217
# Epoch 19/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4068 - accuracy: 0.8225 - val_loss: 0.4107 - val_accuracy: 0.8239
# Epoch 20/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4042 - accuracy: 0.8237 - val_loss: 0.4086 - val_accuracy: 0.8266
# Epoch 21/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4018 - accuracy: 0.8242 - val_loss: 0.4061 - val_accuracy: 0.8277
# Epoch 22/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3994 - accuracy: 0.8272 - val_loss: 0.4034 - val_accuracy: 0.8285
# Epoch 23/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3973 - accuracy: 0.8280 - val_loss: 0.4014 - val_accuracy: 0.8292
# Epoch 24/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3952 - accuracy: 0.8296 - val_loss: 0.3996 - val_accuracy: 0.8304
# Epoch 25/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3931 - accuracy: 0.8294 - val_loss: 0.3976 - val_accuracy: 0.8330
# Epoch 26/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3910 - accuracy: 0.8315 - val_loss: 0.3954 - val_accuracy: 0.8345
# Epoch 27/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3891 - accuracy: 0.8321 - val_loss: 0.3933 - val_accuracy: 0.8372
# Epoch 28/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3871 - accuracy: 0.8332 - val_loss: 0.3915 - val_accuracy: 0.8410
# Epoch 29/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3852 - accuracy: 0.8350 - val_loss: 0.3891 - val_accuracy: 0.8410
# Epoch 30/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3832 - accuracy: 0.8347 - val_loss: 0.3870 - val_accuracy: 0.8406
# Epoch 31/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3815 - accuracy: 0.8371 - val_loss: 0.3851 - val_accuracy: 0.8432
# Epoch 32/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3795 - accuracy: 0.8391 - val_loss: 0.3833 - val_accuracy: 0.8448
# Epoch 33/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3778 - accuracy: 0.8393 - val_loss: 0.3815 - val_accuracy: 0.8440
# Epoch 34/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3760 - accuracy: 0.8418 - val_loss: 0.3798 - val_accuracy: 0.8451
# Epoch 35/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3743 - accuracy: 0.8425 - val_loss: 0.3778 - val_accuracy: 0.8451
# Epoch 36/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3727 - accuracy: 0.8436 - val_loss: 0.3762 - val_accuracy: 0.8455
# Epoch 37/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3712 - accuracy: 0.8438 - val_loss: 0.3744 - val_accuracy: 0.8482
# Epoch 38/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3697 - accuracy: 0.8442 - val_loss: 0.3728 - val_accuracy: 0.8478
# Epoch 39/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3682 - accuracy: 0.8442 - val_loss: 0.3712 - val_accuracy: 0.84820s - loss: 0.3676 - accuracy
# Epoch 40/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3670 - accuracy: 0.8446 - val_loss: 0.3696 - val_accuracy: 0.8478
# Epoch 41/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3655 - accuracy: 0.8485 - val_loss: 0.3683 - val_accuracy: 0.8470
# Epoch 42/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3642 - accuracy: 0.8462 - val_loss: 0.3668 - val_accuracy: 0.8474
# Epoch 43/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3631 - accuracy: 0.8479 - val_loss: 0.3653 - val_accuracy: 0.8489
# Epoch 44/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3620 - accuracy: 0.8479 - val_loss: 0.3641 - val_accuracy: 0.8501
# Epoch 45/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3608 - accuracy: 0.8487 - val_loss: 0.3631 - val_accuracy: 0.8508
# Epoch 46/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3597 - accuracy: 0.8490 - val_loss: 0.3618 - val_accuracy: 0.8493
# Epoch 47/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3587 - accuracy: 0.8507 - val_loss: 0.3606 - val_accuracy: 0.8508
# Epoch 48/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3576 - accuracy: 0.8498 - val_loss: 0.3597 - val_accuracy: 0.8512
# Epoch 49/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3565 - accuracy: 0.8502 - val_loss: 0.3592 - val_accuracy: 0.8527
# Epoch 50/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3556 - accuracy: 0.8513 - val_loss: 0.3575 - val_accuracy: 0.8527
# Epoch 51/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3546 - accuracy: 0.8520 - val_loss: 0.3566 - val_accuracy: 0.8531
# Epoch 52/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3536 - accuracy: 0.8513 - val_loss: 0.3557 - val_accuracy: 0.8542
# Epoch 53/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3526 - accuracy: 0.8517 - val_loss: 0.3550 - val_accuracy: 0.8557
# Epoch 54/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3518 - accuracy: 0.8526 - val_loss: 0.3545 - val_accuracy: 0.8580
# Epoch 55/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3512 - accuracy: 0.8517 - val_loss: 0.3531 - val_accuracy: 0.8584
# Epoch 56/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3503 - accuracy: 0.8528 - val_loss: 0.3521 - val_accuracy: 0.8584
# Epoch 57/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3496 - accuracy: 0.8545 - val_loss: 0.3517 - val_accuracy: 0.8580
# Epoch 58/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3491 - accuracy: 0.8524 - val_loss: 0.3512 - val_accuracy: 0.8588
# Epoch 59/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3482 - accuracy: 0.8535 - val_loss: 0.3505 - val_accuracy: 0.8595
# Epoch 60/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3476 - accuracy: 0.8541 - val_loss: 0.3506 - val_accuracy: 0.8591
# Epoch 61/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3470 - accuracy: 0.8548 - val_loss: 0.3494 - val_accuracy: 0.8614
# Epoch 62/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3465 - accuracy: 0.8530 - val_loss: 0.3490 - val_accuracy: 0.8618
# Epoch 63/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3459 - accuracy: 0.8528 - val_loss: 0.3485 - val_accuracy: 0.8622
# Epoch 64/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3453 - accuracy: 0.8531 - val_loss: 0.3482 - val_accuracy: 0.8629
# Epoch 65/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3449 - accuracy: 0.8530 - val_loss: 0.3481 - val_accuracy: 0.8633
# Epoch 66/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3443 - accuracy: 0.8533 - val_loss: 0.3476 - val_accuracy: 0.8637
# Epoch 67/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3438 - accuracy: 0.8539 - val_loss: 0.3470 - val_accuracy: 0.8633
# Epoch 68/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3433 - accuracy: 0.8541 - val_loss: 0.3468 - val_accuracy: 0.8644
# Epoch 69/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3426 - accuracy: 0.8545 - val_loss: 0.3465 - val_accuracy: 0.8648
# Epoch 70/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3424 - accuracy: 0.8541 - val_loss: 0.3461 - val_accuracy: 0.8641
# Epoch 71/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3417 - accuracy: 0.8537 - val_loss: 0.3463 - val_accuracy: 0.8644
# Epoch 72/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3413 - accuracy: 0.8554 - val_loss: 0.3456 - val_accuracy: 0.8626
# Epoch 73/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3409 - accuracy: 0.8556 - val_loss: 0.3458 - val_accuracy: 0.8622
# Epoch 74/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3407 - accuracy: 0.8558 - val_loss: 0.3455 - val_accuracy: 0.8644
# Epoch 75/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3403 - accuracy: 0.8565 - val_loss: 0.3450 - val_accuracy: 0.8633
# Epoch 76/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3400 - accuracy: 0.8558 - val_loss: 0.3451 - val_accuracy: 0.8618
# Epoch 77/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3397 - accuracy: 0.8558 - val_loss: 0.3450 - val_accuracy: 0.8633
# Epoch 78/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3394 - accuracy: 0.8565 - val_loss: 0.3443 - val_accuracy: 0.8641
# Epoch 79/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3392 - accuracy: 0.8563 - val_loss: 0.3442 - val_accuracy: 0.8644
# Epoch 80/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3388 - accuracy: 0.8576 - val_loss: 0.3445 - val_accuracy: 0.8637
# Epoch 81/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3387 - accuracy: 0.8580 - val_loss: 0.3442 - val_accuracy: 0.8629
# Epoch 82/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3384 - accuracy: 0.8600 - val_loss: 0.3442 - val_accuracy: 0.8637
# Epoch 83/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3382 - accuracy: 0.8589 - val_loss: 0.3442 - val_accuracy: 0.8644
# Epoch 84/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3379 - accuracy: 0.8574 - val_loss: 0.3440 - val_accuracy: 0.8633
# Epoch 85/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3378 - accuracy: 0.8578 - val_loss: 0.3437 - val_accuracy: 0.8637
# Epoch 86/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3376 - accuracy: 0.8576 - val_loss: 0.3436 - val_accuracy: 0.8633
# Epoch 87/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3372 - accuracy: 0.8587 - val_loss: 0.3436 - val_accuracy: 0.8629
# Epoch 88/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3371 - accuracy: 0.8593 - val_loss: 0.3435 - val_accuracy: 0.8629
# Epoch 89/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3370 - accuracy: 0.8597 - val_loss: 0.3430 - val_accuracy: 0.8629
# Epoch 90/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3367 - accuracy: 0.8593 - val_loss: 0.3427 - val_accuracy: 0.8626
# Epoch 91/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3365 - accuracy: 0.8600 - val_loss: 0.3427 - val_accuracy: 0.8637
# Epoch 92/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3362 - accuracy: 0.8602 - val_loss: 0.3427 - val_accuracy: 0.8629
# Epoch 93/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3359 - accuracy: 0.8586 - val_loss: 0.3426 - val_accuracy: 0.8641
# Epoch 94/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3359 - accuracy: 0.8614 - val_loss: 0.3420 - val_accuracy: 0.8641
# Epoch 95/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3356 - accuracy: 0.8600 - val_loss: 0.3418 - val_accuracy: 0.8637
# Epoch 96/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3354 - accuracy: 0.8614 - val_loss: 0.3423 - val_accuracy: 0.8633
# Epoch 97/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3352 - accuracy: 0.8589 - val_loss: 0.3419 - val_accuracy: 0.8648
# Epoch 98/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3351 - accuracy: 0.8612 - val_loss: 0.3418 - val_accuracy: 0.8644
# Epoch 99/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3350 - accuracy: 0.8604 - val_loss: 0.3412 - val_accuracy: 0.8641
# Epoch 100/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3349 - accuracy: 0.8608 - val_loss: 0.3411 - val_accuracy: 0.8648

# %% [markdown]
# # list all data in history

# %%
print(model_history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # summarize history for accuracy

# %% [markdown]
# plt.plot(model_history.history['accuracy'])
# plt.plot(model_history.history['val_acc'])
# plt.title('model accuracy')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %% [markdown]
# # summarize history for loss

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Making the predictions and evaluating the model

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
print(y_pred)
# Out:
# [[False]
#  [False]
#  [False]
#  ...
#  [False]
#  [False]
#  [False]]

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1509   80]
#  [ 212  199]]

# %%
# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)

# %%
print(score)
# Out:
# 0.854
